# %%
from pymongo import MongoClient
import requests
import json
import pandas as pd
import numpy as np
from getpass import getpass
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %% [markdown]
# ### Conectar con la Collection en Mongo

# %%
def access_mdb_local_collection (database, collection):

    """ Function that returns a collection inside a DataBase 
    host in my local Server """

    # 1. Connect to my local Server
    client = MongoClient("localhost:27017")
    
    # 2. Access a DataBase:
    db = client[database]

    # 3. Acces a collection inside the given DataBase
    c = db.get_collection(collection)

    # 4. Return collection into a given DataBase host in a given Server
    return c

# %% [markdown]
# ### Categories:
#
# **10061**	Arts and Entertainment > Stadium > Basketball Stadium
#     If nothign try: 10051	Arts and Entertainment > Stadium
#
# **16033**	Landmarks and Outdoors > Park > Dog Park
#
# **13377**	Dining and Drinking > Restaurant > Vegan
#
# **10032**	Arts and Entertainment > Night Club
#
# **19031**	Travel and Transportation > Transport Hub > Airport
# **19066**	Travel and Transportation > Train
#
#
#
# **11030**	Business and Professional Services > Design Studio

# %%
markers = {
    10061: ["stadium" , "orange", "black", "baseball"],
    16033: ["dog_park", "green", "white", "dog"],
    13377: ["vegan_rest", "white", "green", "leaf"],
    10032: ["nigth_club", "black", "white", "champagne-glasses"],
    19066: ["transport", "blue", "white", "plane-departure"],
    19031: ["transport", "blue", "white", "plane-departure"],
    11030: ["dessing", "pink", "black", "pen-nib"]
    
}

# %% [markdown]
# # MAIN:

# %%
locations = { "Madrid" : "40.4193326,-3.6930825"}

# %%
c = access_mdb_local_collection ("ironhack", "madrid")

# %%
def extract_parameters(i):
            
            name = i["name"]
            
            lat = i["geocodes"]["main"]["latitude"]
            lon = i["geocodes"]["main"]["longitude"]
            
            #can have more than one:
            cat_list = [x["id"] for x in i["categories"]]
            
            try:
                city = i["location"]["locality"]
            except KeyError:
                city = np.nan
            
            params = {"city":city, "name": name, "cat_code":cat_list, "lat":lat, "lon":lon}
            
            return params

# %%
projection = { "_id":0,"categories":1, "geocodes":1,"name":1}
datos = list(c.find({},projection))

register = {"city": [], "place_name":[], "categories":[],"lat":[], "lon":[]}

for i in datos:
    
    info = extract_parameters(i)
    
    register["city"].append("madrid")
    register["place_name"].append(info["name"])
    register["categories"].append(info["cat_code"])
    register["lat"].append(info["lat"])
    register["lon"].append(info["lon"])

df = pd.DataFrame(register)

# %%
markers = {
    10051: ["stadium" , "orange", "black", "baseball"],
    16033: ["dog_park", "green", "white", "dog"],
    13377: ["vegan_rest", "white", "green", "leaf"],
    10032: ["nigth_club", "black", "white", "champagne-glasses"],
    19066: ["transport", "blue", "white", "plane-departure"],
    19031: ["transport", "blue", "white", "plane-departure"],
    11030: ["dessing", "pink", "black", "pen-nib"]
    
}

# %%
lista_conici = list(markers.keys())
lista_conici
# Out:
# [10051, 16033, 13377, 10032, 19066, 19031, 11030]

# %%
df.reset_index(inplace=True, drop=True)

# %%
def obtener_primera_coincidencia(categorias):
    for categoria in categorias:
        if categoria in lista_conici:
            return categoria
    return np.nan

# Aplicar la función a la columna 'Categorias' y crear una nueva columna 'Nueva_Columna'
df['match'] = df["categories"].apply(obtener_primera_coincidencia)

# %%
df
# Out:
#        city                                  place_name      categories  \
# 0    madrid                                    Barganzo  [13286, 13377]
# 1    madrid                                Gunilla Club         [10032]
# 2    madrid                                     Giselle         [10032]
# 3    madrid                                     Rubicon         [10032]
# 4    madrid                                   Studio 42  [10032, 13003]
# ..      ...                                         ...             ...
# 254  madrid        Polideportivo Municipal de Orcasitas         [10051]
# 255  madrid              Plaza de Toros de Vista Alegre  [10051, 16026]
# 256  madrid  Iam Informatica del Ayuntamiento de Madrid         [10051]
# 257  madrid                              La Caja Mágica         [10051]
# 258  madrid                          Stade Ramon Urtubi         [10051]
#
#            lat       lon    match
# 0    40.421086 -3.696823  13377.0
# 1    40.422582 -3.690987  10032.0
# 2    40.422683 -3.691142  10032.0
# 3    40.422592 -3.689909  10032.0
# 4    40.422931 -3.690610  10032.0
# ..         ...       ...      ...
# 254  40.375927 -3.712630  10051.0
# 255  40.386375 -3.738919  10051.0
# 256  40.383820 -3.648450  10051.0
# 257  40.368927 -3.684090  10051.0
# 258  40.457680 -3.639086  10051.0
#
# [259 rows x 6 columns]

# %%
def icon_set(category_code): # marker of categorye [10051]
    
    icon =  Icon(
            color = markers[category_code][1], #red
            icon_color = markers[category_code][2], #black
            icon = markers[category_code][3], #dog
            prefix="fa" # font-awesome website: fa
                )
            
    return icon

# %%
def city_markers(df, to_map):
    
        for index, row in df.iterrows():
            
            if df.iloc[index]["match"] == np.nan:
                continue
            else:
                category_code = df.iloc[index]["match"]
                #print(category_code)
                try:
                    #Set the icon for that kind of place:
                    icon_conf = icon_set(category_code)

                    #Extract position in witch locates:
                    lat = df.iloc[index]["lat"]
                    lon = df.iloc[index]["lon"]
                    coordenates = [lat, lon]

                    #Retrieve the category_code name (ej:"stadium")
                    # we know the position in the dictionary
                    lable = markers[category_code][0]

                    #Set the marker:
                    marker = Marker(coordenates, tooltip=lable ,  icon=icon_conf)

                    marker.add_to(to_map)
                
                
                except KeyError:
                    continue
        
        return

# %%
city_map = Map([40.4193326,-3.6930825], zoom_start=13,  tiles='CartoDB positron')

city_markers(df, city_map)

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_008b61c25a5e31c4ee49b4a70f6fbcfe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_008b61c25a5e31c4ee49b4a70f6fbcfe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_008b61c25a5e31c4ee49b4a70f6fbcfe = L.map(
#                 &quot;map_008b61c25a5e31c4ee49b4a70f6fbcfe&quot;,
#                 {
#                     center: [40.4193326, -3.6930825],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_407fccc6ebbaea37547e463b6bbaadd5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_407fccc6ebbaea37547e463b6bbaadd5.addTo(map_008b61c25a5e31c4ee49b4a70f6fbcfe);
#
#
#             var marker_f230a362d3ee2db22c7018cff4b14ff3 = L.marker(
#                 [40.421086, -3.696823],
#                 {}
#             ).addTo(map_008b61c25a5e31c4ee49b4a70f6fbcfe);
#
#
#             var icon_41c0d109612720334e8d134f540d5370 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;green&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f230a362d3ee2db22c7018cff4b14ff3.setIcon(icon_41c0d109612720334e8d134f540d5370);
#
#
#             marker_f230a362d3ee2db22c7018cff4b14ff3.bindTooltip(
#                 `&lt;div&gt;
#                      vegan_rest
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7d9cc7bcc2846ba533f0e2157f8d0557 = L.marker(
#                 [40.422582, -3.690987],
#                 {}
#             ).addTo(map_008b61c25a5e31c4ee49b4a70f6fbcfe);
#
#
#             var icon_0972b2aaf7c9b928c26fc1a15ca0c86d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;champagne-glasses&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7d9cc7bcc2846ba533f0e2157f8d0557.setIcon(icon_0972b2aaf7c9b928c26fc1a15ca0c86d);
#
#
#             marker_7d9cc7bcc2846ba533f0e2157f8d0557.bindTooltip(
#                 `&lt;div&gt;
#                      nigth_club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f37341d03a20ec2f7a32cc4946449030 = L.marker(
#                 [40.422683, -3.691142],
#                 {}
#             ).addTo(map_008b61c25a5e31c4ee49b4a70f6fbcfe);
#
#
#             var icon_830deac992c38fbc4ea916056e4247ad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;champagne-glasses&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f37341d03a20ec2f7a32cc4946449030.setIcon(icon_830deac992c38fbc4ea916056e4247ad);
#
#
#             marker_f37341d03a20ec2f7a32cc4946449030.bindTooltip(
#                 `&lt;div&gt;
#                      nigth_club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6333802eac8ba4672ebb4715e8ff4ffb = L.marker(
#                 [40.422592, -3.689909],
#                 {}
#             ).addTo(map_008b61c25a5e31c4ee49b4a70f6fbcfe);
#
#
#             var icon_794911d09eed3cb74176b55c5f0a7e8b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;champagne-glasses&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6333802eac8ba4672ebb4715e8ff4ffb.setIcon(icon_794911d09eed3cb74176b55c5f0a7e8b);
#
#
#             marker_6333802eac8ba4672ebb4715e8ff4ffb.bindTooltip(
#                 `&lt;div&gt;
#                      nigth_club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fc4dded138996413bcb7b2d5a085f66f = L.marker(
#                 [40.422931, -3.69061],
#                 {}
#             ).addTo(map_008b61c25a5e31c4ee49b4a70f6fbcfe);
#
#
#             var icon_417d3a4f6135f7c8d62597d2aca15a2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;champagne-glasses&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );

# %%
city_map.save("otros_madrid_tagsmap.html")

# %%
punto:

40.4193367,-3.6956574
