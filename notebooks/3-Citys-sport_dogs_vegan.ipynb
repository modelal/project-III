# %%
from pymongo import MongoClient
import requests
import json
import pandas as pd
import numpy as np
from getpass import getpass
import os

import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %%
token = getpass()
# Out:
# ········

# %% [markdown]
# # Acces a db collection

# %%
def access_mdb_local_collection (database, collection):

    """ Function that returns a collection inside a DataBase 
    host in my local Server """

    # 1. Connect to my local Server
    client = MongoClient("localhost:27017")
    
    # 2. Access a DataBase:
    db = client[database]

    # 3. Acces a collection inside the given DataBase
    c = db.get_collection(collection)

    # 4. Return collection into a given DataBase host in a given Server
    return c

# %% [markdown]
# ## Extract from FourSquare API

# %%
def foursquare_places(location, radius, query="" ,category = ""):
    
    """
    Search for places by distance on a circular boundary in ForeSquare API and returns a .json()
    Optional filter, venue and/or category can be added
    Response limited to 50 (maximum)

    :location: str : "latidude,longitude" around which to retrieve place information  eg. "43.37012643,-8,39114853"
    :radius: int : radius in meters.define the area to bias search results.  eg. 10000
    :query: str : OPTIONAL:  a string to be matched against all content for this place
    :category: int: OPTIONAL : returns FSQ Places matching the specified id categories
       see category taxonomy -->  https://location.foursquare.com/places/docs/categories

    """


    url = "https://api.foursquare.com/v3/places/search"

    params = {
        "query": query,
        "ll": location,
        "radius":radius,
        "categories":category,
        "limit":50,
        "sort":"DISTANCE"  #Por defecto relevancia. 
    }

    headers = {
        "Accept": "application/json",
        "Authorization": token
    }

    return requests.get(url, params=params, headers=headers).json()

# %% [markdown]
# ## Insert into a given collection:

# %%
def insert_unique_parents(response, mdb_collection):
    
    """
    Inserts the results of a reques that ARE NOT in the 
    given collection AND ARE NOT related to other object(childrens)

    response: --- : what to insert
    collection: ----: where to insert it
    """
    
    # 1. set conter for inserted objects
    inserted = 0
    
    # 3. Get the list of all elements alrready registered in the collection
    registered = [i['fsq_id'] for i in mdb_collection.find({}, {"_id":0,"fsq_id":1})]
    
    # 4. Iterate trough all elements of the response 
    for i in response["results"]:
        
        #Need to meet 2 conditions to be inserted:
        # It is not alrready registered:
        cond1 = i['fsq_id'] not in registered
        
        ## It's not a children of a parent:
        cond2 = "parent" not in list(i["related_places"].keys())
        
        # Check if the conditions are meet:
        if cond1 and cond2 == True:
            mdb_collection.insert_one(i)
            inserted += 1
            
    print(f'{inserted} items inserted into the collection')
               
    return

# %% [markdown]
# ## Visualization Functions:

# %% [markdown]
# Aqui la funcion cabia con respecto al anterior

# %%
def city_places(city, collection):
    
    c = access_mdb_local_collection ("foursquare", collection)
    
    # 1. Set the filter to the objects --> REVIEW option just locality??¿?¿ lo de Valencia - comunidad valencia 
    filt = {}
    
    # 2. Select the filds that we want to target:
    projection = { "_id":0,"categories":1, "geocodes":1,"name":1}
    
    # 3. Extract data
    datos = list(c.find(filt,projection))
    
    # 4. Generate an empty dictionary with the categories to save:
    register = {"city": [], "place_name":[], "lable":[],"lat":[], "lon":[]}
    
    # 5. Iterate trowh all elements found:
    for i in datos:

        info = extract_parameters(i) # info it's a dictionary 
            # example --> info = {"name": name, "cat_code":cat_code, "lat":lat, "lon":lon}
            
            
        name = info["name"]
        lable =info["cat_code"]
        lat = info["lat"]
        lon =  info["lon"]
        
        register["city"].append(city)
        register["place_name"].append(name)
        register["lable"].append(lable)
        register["lat"].append(lat)
        register["lon"].append(lon)

        df = pd.DataFrame(register)
        
    return df

# %%
def extract_parameters(i):
            
            name = i["name"]
            
            lat = i["geocodes"]["main"]["latitude"]
            lon = i["geocodes"]["main"]["longitude"]
            
            # as elements can have more than one categorie
            #we need to make sure we use the ones that we
            #have consider in markers. We know they all have
            #at least one of them because we extract the 
            #info from the API using categorie filter:
            
            
            cat_list = [x["id"] for x in i["categories"]]
            cat_code = [key for key in markers.keys() if key in cat_list][0]
              
            """
            The same before comprehension list:
            
            for key in markers.keys():
                if key in cat_list
                    cat_code = key
                    
            With the comprehension list, we need to acces the first 
            element -> we know there will be just one.
            """
            params = {"name": name, "cat_code":cat_code, "lat":lat, "lon":lon}
            
            return params

# %%
def icon_set(category_code): # marker of categorye [10051]
    
    icon =  Icon(
            color = markers[category_code][1], #red
            icon_color = markers[category_code][2], #black
            icon = markers[category_code][3], #dog
            prefix="fa" # font-awesome website: fa
                )
            
    return icon

# %%
def city_markers(df, to_map):
    
        for index, row in df.iterrows():
            
            #What kind of place it is: (code)
            category_code = df.iloc[index]["lable"]
            
            #Set the icon for that kind of place:
            icon_conf = icon_set(category_code)
            
            #Extract position in witch locates:
            lat = df.iloc[index]["lat"]
            lon = df.iloc[index]["lon"]
            coordenates = [lat, lon]
            
            #Retrieve the category_code name (ej:"stadium")
            # we know the position in the dictionary
            lable = markers[category_code][0]
            
            #Set the marker:
            marker = Marker(coordenates, tooltip=lable ,  icon=icon_conf)
            
            marker.add_to(to_map)
        
        return

# %%
def heat_map(df, to_map):
    
    HeatMap(data = df[["lat", "lon"]]).add_to(to_map)
        
    return

# %% [markdown]
# # MAIN:

# %% [markdown]
# ### Extraer Datos de las ciudades seleccionadas:

# %%
Posibles = {
    "Madrid" : "40.40841191,-3.68760088",
    "Barcelona" : "41.38424664,2.17634927",
    "Valencia" : "39.47534441,-0.37565717",
    "Sevilla" : "37.38620512,-5.99251368"   
}

# %% [markdown]
# ### MADRID

# %%
location_dict = {"Madrid" : "40.40841191,-3.68760088"}

# %% [markdown]
# 1. Extract From API, Insert into MG

# %%
categories = {
    "stadium" : 10051,
    "dog_park" : 16033,
    "vegan_rest" : 13377,
    #"nigth_club" : 10032
}

#Para cada categoria:
for key, cat in categories.items():
    
    location = location_dict["Madrid"]
    radius = 10000 #(10km)
    query = ""
    category = cat
        
    #print(f'----Location {key}, category {key2}----')
    
    # EXTRACT 
    response = foursquare_places(location, radius, query ,category)
    
    #CONCET
    mdb_collection = access_mdb_local_collection ("foursquare", "madrid")
    
    #INSERT:
    insert_unique_parents(response, mdb_collection)
    
    #desable printing
    #print(f'---------------------------------------')
# Out:
# 0 items inserted into the collection
# 0 items inserted into the collection
# 0 items inserted into the collection

# %% [markdown]
# 2. Extract from Mongo and Create a DF

# %%
markers = {
    10051: ["stadium" , "orange", "black", "baseball"],
    16033: ["dog_park", "green", "white", "dog"],
    13377: ["vegan_rest", "white", "green", "leaf"],
    #10032: ["nigth_club", "black", "white", "champagne-glasses"]
}

# %%
df = city_places("madrid", "madrid")

# %%
# Create the map 
city_map = Map([40.40841191,-3.68760088], zoom_start=13,  tiles='CartoDB positron')

#Add the markers 
city_markers(df, city_map)

city_map.save(f"{location}_markmap.html")

city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b67df28ae9f4617a895e127135fae395 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b67df28ae9f4617a895e127135fae395&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b67df28ae9f4617a895e127135fae395 = L.map(
#                 &quot;map_b67df28ae9f4617a895e127135fae395&quot;,
#                 {
#                     center: [40.40841191, -3.68760088],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e513f0766710f2458881631dd0cde84 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0e513f0766710f2458881631dd0cde84.addTo(map_b67df28ae9f4617a895e127135fae395);
#
#
#             var marker_e7b18d9db349c916902ef3c4feee3aae = L.marker(
#                 [40.407525, -3.676515],
#                 {}
#             ).addTo(map_b67df28ae9f4617a895e127135fae395);
#
#
#             var icon_e9aa1ddf44f78f9220f81834cda36abb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e7b18d9db349c916902ef3c4feee3aae.setIcon(icon_e9aa1ddf44f78f9220f81834cda36abb);
#
#
#             marker_e7b18d9db349c916902ef3c4feee3aae.bindTooltip(
#                 `&lt;div&gt;
#                      stadium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_533561c1091b5c718cb5af3c5b241729 = L.marker(
#                 [40.422567, -3.688308],
#                 {}
#             ).addTo(map_b67df28ae9f4617a895e127135fae395);
#
#
#             var icon_f9fb77790bd8843980bdf4d950306a97 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_533561c1091b5c718cb5af3c5b241729.setIcon(icon_f9fb77790bd8843980bdf4d950306a97);
#
#
#             marker_533561c1091b5c718cb5af3c5b241729.bindTooltip(
#                 `&lt;div&gt;
#                      stadium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_69c28d4563e82452bbad663b12cb59c0 = L.marker(
#                 [40.394378, -3.691316],
#                 {}
#             ).addTo(map_b67df28ae9f4617a895e127135fae395);
#
#
#             var icon_0e514c8bf3a6302cfd0a064cf3e58eb3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_69c28d4563e82452bbad663b12cb59c0.setIcon(icon_0e514c8bf3a6302cfd0a064cf3e58eb3);
#
#
#             marker_69c28d4563e82452bbad663b12cb59c0.bindTooltip(
#                 `&lt;div&gt;
#                      stadium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_afd53b7ef3ae1bfe4ac8f78710f5cf54 = L.marker(
#                 [40.422708, -3.688101],
#                 {}
#             ).addTo(map_b67df28ae9f4617a895e127135fae395);
#
#
#             var icon_2d4dbc6dc6fed269d417411a1ba84e2c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_afd53b7ef3ae1bfe4ac8f78710f5cf54.setIcon(icon_2d4dbc6dc6fed269d417411a1ba84e2c);
#
#
#             marker_afd53b7ef3ae1bfe4ac8f78710f5cf54.bindTooltip(
#                 `&lt;div&gt;
#                      stadium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1edb53a6d055cf94ad1cbb67569089f0 = L.marker(
#                 [40.41678, -3.70379],
#                 {}
#             ).addTo(map_b67df28ae9f4617a895e127135fae395);
#
#
#             var icon_a8bf8606bb0e589e498e0c7ebff938ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1edb53a6d055cf94ad1cbb67569089

# %%
#map and dataframe
city_map =  Map([40.40841191,-3.68760088], zoom_start=13,  tiles='CartoDB positron')
heat_map(df, city_map)
city_map.save(f"{location}_heatmap.html")
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5
, -3.702979], [40.415657, -3.701408], [40.419449, -3.678988], [40.410378, -3.704513], [40.415757, -3.702744], [40.408302, -3.669146], [40.408314, -3.669064], [40.413139, -3.705052], [40.41058, -3.705997], [40.421086, -3.696823], [40.394574, -3.694162], [40.421152, -3.697465], [40.421439, -3.698435], [40.422178, -3.696593], [40.419214, -3.702818], [40.42336, -3.698162], [40.421275, -3.702792], [40.423439, -3.700042], [40.42603, -3.68425], [40.419121, -3.706685], [40.421935, -3.703509], [40.42582, -3.696206], [40.42415, -3.700815], [40.41249, -3.711852], [40.416388, -3.710516], [40.427545, -3.683535], [40.424574, -3.701937], [40.4138, -3.712142], [40.419019, -3.709408], [40.424565, -3.702401], [40.422322, -3.706102], [40.428724, -3.687555], [40.425267, -3.703636], [40.425387, -3.704428], [40.423756, -3.709173], [40.427409, -3.703904], [40.428507, -3.70319]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_d38a6788d968e47c50fa1dfae8ef4afc.addTo(map_5ed9ab0f8d68495b37809b452dda9a90);
#
#
#             tile_layer_124cf5b6139e4daf470b435c5c85477c.addTo(map_5ed9ab0f8d68495b37809b452dda9a90);
#
#
#             heat_map_d38a6788d968e47c50fa1dfae8ef4afc.addTo(map_5ed9ab0f8d68495b37809b452dda9a90);
#
# &lt;/script&gt;
# &l

# %%
Circle(
    location= [40.40841191,-3.68760088],
    radius=1000,
    color='blue',
    fill=True,
    fill_color='blue',
    fill_opacity=0.3,
    tooltip=f'Radio:m'
).add_to(city_map)

# %% [markdown]
# ### VALENCIA

# %%
location_dict = {"Valencia" : "39.47534441,-0.37565717"}

# %% [markdown]
# 1. Extract From API, Insert into MG

# %%
categories = {
    "stadium" : 10051,
    "dog_park" : 16033,
    "vegan_rest" : 13377,
    #"nigth_club" : 10032
}

#Para cada categoria:
for key, cat in categories.items():
    
    location = location_dict["Valencia"]
    radius = 10000 #(10km)
    query = ""
    category = cat
        
    #print(f'----Location {key}, category {key2}----')
    
    # EXTRACT 
    response = foursquare_places(location, radius, query ,category)
    
    #CONCET
    mdb_collection = access_mdb_local_collection ("foursquare", "valencia")
    
    #INSERT:
    insert_unique_parents(response, mdb_collection)
    
    #desable printing
    #print(f'---------------------------------------')
# Out:
# 0 items inserted into the collection
# 0 items inserted into the collection
# 0 items inserted into the collection

# %% [markdown]
# 2. Extract from Mongo and Create a DF

# %%
markers = {
    10051: ["stadium" , "orange", "black", "baseball"],
    16033: ["dog_park", "green", "white", "dog"],
    13377: ["vegan_rest", "white", "green", "leaf"],
    #10032: ["nigth_club", "black", "white", "champagne-glasses"]
}

# %%
df = city_places("valencia", "valencia")

# %%
# Create the map 
city_map = Map([39.47534441,-0.37565717], zoom_start=13,  tiles='CartoDB positron')

#Add the markers 
city_markers(df, city_map)

city_map.save(f"{location}_markmap.html")

city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13464f27c8509db8173d420457d1ba40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13464f27c8509db8173d420457d1ba40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13464f27c8509db8173d420457d1ba40 = L.map(
#                 &quot;map_13464f27c8509db8173d420457d1ba40&quot;,
#                 {
#                     center: [39.47534441, -0.37565717],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d82ee0b624c3c86ceee9a9437b17c05 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6d82ee0b624c3c86ceee9a9437b17c05.addTo(map_13464f27c8509db8173d420457d1ba40);
#
#
#             var marker_90b7b4d8c9cfb0be3a6616fdba3fc11f = L.marker(
#                 [39.480548, -0.374451],
#                 {}
#             ).addTo(map_13464f27c8509db8173d420457d1ba40);
#
#
#             var icon_82f48928f05176930a1b21cb2c536541 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_90b7b4d8c9cfb0be3a6616fdba3fc11f.setIcon(icon_82f48928f05176930a1b21cb2c536541);
#
#
#             marker_90b7b4d8c9cfb0be3a6616fdba3fc11f.bindTooltip(
#                 `&lt;div&gt;
#                      stadium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f7d343dc1808a94c32f724e9115a2329 = L.marker(
#                 [39.482172, -0.381882],
#                 {}
#             ).addTo(map_13464f27c8509db8173d420457d1ba40);
#
#
#             var icon_e6e21ea51f313cfd28f5c4d7588b0c62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f7d343dc1808a94c32f724e9115a2329.setIcon(icon_e6e21ea51f313cfd28f5c4d7588b0c62);
#
#
#             marker_f7d343dc1808a94c32f724e9115a2329.bindTooltip(
#                 `&lt;div&gt;
#                      stadium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd766b263ab441365f1a3225e968d297 = L.marker(
#                 [39.482867, -0.380608],
#                 {}
#             ).addTo(map_13464f27c8509db8173d420457d1ba40);
#
#
#             var icon_b9faab5a5b42453693732f1e068b0dad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dd766b263ab441365f1a3225e968d297.setIcon(icon_b9faab5a5b42453693732f1e068b0dad);
#
#
#             marker_dd766b263ab441365f1a3225e968d297.bindTooltip(
#                 `&lt;div&gt;
#                      stadium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_405fc928a5a021465ce0f7ce78ebab3d = L.marker(
#                 [39.474622, -0.358247],
#                 {}
#             ).addTo(map_13464f27c8509db8173d420457d1ba40);
#
#
#             var icon_953345509e7cd41f89c16d29be4f2f4b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_405fc928a5a021465ce0f7ce78ebab3d.setIcon(icon_953345509e7cd41f89c16d29be4f2f4b);
#
#
#             marker_405fc928a5a021465ce0f7ce78ebab3d.bindTooltip(
#                 `&lt;div&gt;
#                      stadium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c047683b8eb863fd2ca4ac76b0a241a2 = L.marker(
#                 [39.474542, -0.358166],
#                 {}
#             ).addTo(map_13464f27c8509db8173d420457d1ba40);
#
#
#             var icon_7ad8404f1a03f46bfb4af82da86d6c19 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baseball&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c047683b8eb863fd2ca4ac76b0a2

# %%
#map and dataframe
city_map =  Map([39.47534441,-0.37565717], zoom_start=13,  tiles='CartoDB positron')
heat_map(df, city_map)
city_map.save(f"{location}_heatmap.html")
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_323eef891866712178dc3951cde69c3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_323eef891866712178dc3951cde69c3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_323eef891866712178dc3951cde69c3b = L.map(
#                 &quot;map_323eef891866712178dc3951cde69c3b&quot;,
#                 {
#                     center: [39.47534441, -0.37565717],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83644c251aed31b5d0d65cb9fc57551b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer